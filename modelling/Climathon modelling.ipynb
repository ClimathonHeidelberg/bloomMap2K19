# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re as re

# %%
df = pd.read_csv('2019.csv', sep=',')
df
# Out:
#      Unnamed: 0         Datum  Temp. A.         Temp. A..1        Temp. A..2  \
# 0             0    01.01.2019    6,3 °C   Min. 23:505,3 °C  Max. 12:556,9 °C
# 1             1    02.01.2019    3,5 °C  Min. 23:55-1,8 °C  Max. 14:156,4 °C
# 2             2    03.01.2019   -1,0 °C  Min. 06:20-3,9 °C  Max. 19:050,8 °C
# 3             3    04.01.2019    1,3 °C  Min. 01:25-0,3 °C  Max. 14:302,9 °C
# 4             4    05.01.2019    2,9 °C   Min. 09:351,7 °C  Max. 23:454,6 °C
# ..          ...           ...       ...                ...               ...
# 301         301       Minimum   -6,7 °C            -6,7 °C           -6,7 °C
# 302         302     Max-Datum  25.07.19           25.07.19          25.07.19
# 303         303      Max-Zeit     17:10              17:10             17:10
# 304         304       Maximum   38,9 °C            38,9 °C           38,9 °C
# 305         305  Durchschnitt   14,0 °C            14,0 °C           14,0 °C
#
#     Feuchte A.    Feuchte A..1    Feuchte A..2   Luftdruck  \
# 0         93 %  Min. 23:2582 %  Max. 00:0096 %  1029,0 hPa
# 1         77 %  Min. 15:0560 %  Max. 23:5587 %  1032,1 hPa
# 2         92 %  Min. 00:0087 %  Max. 19:4595 %  1037,3 hPa
# 3         93 %  Min. 15:3090 %  Max. 09:3096 %  1035,8 hPa
# 4         96 %  Min. 00:0094 %  Max. 10:2596 %  1029,6 hPa
# ..         ...             ...             ...         ...
# 301       19 %            19 %            19 %   988,1 hPa
# 302   13.01.19        13.01.19        13.01.19    23.02.19
# 303      10:25           10:25           10:25       09:35
# 304       97 %            97 %            97 %  1038,7 hPa
# 305       71 %            71 %            71 %  1015,6 hPa
#
#               Luftdruck.1  ...      Solar             Solar.1  Taupunkt  \
# 0    Min. 17:451026,5 hPa  ...    21 W/m²   Max. 12:3056 W/m²    5,3 °C
# 1    Min. 00:001027,9 hPa  ...    78 W/m²  Max. 13:40297 W/m²   -0,3 °C
# 2    Min. 00:001036,4 hPa  ...    36 W/m²   Max. 09:5081 W/m²   -2,1 °C
# 3    Min. 20:151033,1 hPa  ...    70 W/m²  Max. 12:35255 W/m²    0,4 °C
# 4    Min. 13:301028,0 hPa  ...    11 W/m²   Max. 14:4026 W/m²    2,2 °C
# ..                    ...  ...        ...                 ...       ...
# 301             988,1 hPa  ...          -                   -  -12,4 °C
# 302              23.02.19  ...   07.07.19            07.07.19  26.07.19
# 303                 09:35  ...      12:40               12:40     17:40
# 304            1038,7 hPa  ...  1146 W/m²           1146 W/m²   24,4 °C
# 305            1015,6 hPa  ...   216 W/m²            216 W/m²    8,1 °C
#
#            Taupunkt.1         Taupunkt.2 Windchill       Windchill.1  \
# 0    Max. 00:006,0 °C   Min. 23:502,7 °C    6,3 °C  Max. 12:556,9 °C
# 1    Max. 00:002,7 °C  Min. 23:45-3,7 °C    3,4 °C  Max. 14:356,3 °C
# 2    Max. 19:550,1 °C  Min. 06:20-5,1 °C   -1,0 °C  Max. 19:100,8 °C
# 3    Max. 13:401,7 °C  Min. 01:25-1,1 °C    1,3 °C  Max. 14:302,9 °C
# 4    Max. 23:454,0 °C   Min. 09:351,0 °C    2,9 °C  Max. 23:454,6 °C
# ..                ...                ...       ...               ...
# 301          -12,4 °C           -12,4 °C   -6,7 °C           -6,7 °C
# 302          26.07.19           26.07.19  25.07.19          25.07.19
# 303             17:40              17:40     17:10             17:10
# 304           24,4 °C            24,4 °C   38,9 °C           38,9 °C
# 305            8,1 °C             8,1 °C   14,0 °C           14,0 °C
#
#            Windchill.2             Windböen                   Windböen.1
# 0     Min. 23:254,9 °C     6,3 km/h (2 Bft)  Max. 23:5524,1 km/h (4 Bft)
# 1    Min. 23:55-1,8 °C     9,5 km/h (2 Bft)  Max. 02:0025,7 km/h (4 Bft)
# 2    Min. 06:20-3,9 °C     1,3 km/h (1 Bft)   Max. 08:208,0 km/h (2 Bft)
# 3    Min. 01:25-0,3 °C     0,9 km/h (0 Bft)   Max. 15:258,0 km/h (2 Bft)
# 4     Min. 09:351,7 °C     1,7 km/h (1 Bft)  Max. 12:1511,3 km/h (2 Bft)
# ..                 ...                  ...                          ...
# 301            -6,7 °C     0,0 km/h (0 Bft)             0,0 km/h (0 Bft)
# 302           25.07.19             04.03.19                     04.03.19
# 303              17:10                09:30                        09:30
# 304            38,9 °C  48,3 km/h S (6 Bft)          48,3 km/h S (6 Bft)
# 305            14,0 °C     6,4 km/h (2 Bft)             6,4 km/h (2 Bft)
#
# [306 rows x 32 columns]

# %%
temp = df.iloc[:,[1,2,3,4]]

# %% [markdown]
# temp

# %%
temp.drop(temp.tail(7).index,inplace=True)
temp
# Out:
#           Datum Temp. A.         Temp. A..1         Temp. A..2
# 0    01.01.2019   6,3 °C   Min. 23:505,3 °C   Max. 12:556,9 °C
# 1    02.01.2019   3,5 °C  Min. 23:55-1,8 °C   Max. 14:156,4 °C
# 2    03.01.2019  -1,0 °C  Min. 06:20-3,9 °C   Max. 19:050,8 °C
# 3    04.01.2019   1,3 °C  Min. 01:25-0,3 °C   Max. 14:302,9 °C
# 4    05.01.2019   2,9 °C   Min. 09:351,7 °C   Max. 23:454,6 °C
# ..          ...      ...                ...                ...
# 287  15.10.2019  16,2 °C  Min. 08:0013,2 °C  Max. 12:4521,6 °C
# 288  16.10.2019  13,6 °C  Min. 04:2011,1 °C  Max. 17:5017,2 °C
# 289  17.10.2019  14,9 °C  Min. 01:4012,1 °C  Max. 14:4019,0 °C
# 290  18.10.2019  14,3 °C  Min. 22:3511,4 °C  Max. 12:1017,7 °C
# 291  19.10.2019  13,7 °C  Min. 00:3511,2 °C  Max. 16:2516,4 °C
#
# [292 rows x 4 columns]

# %%
Min=temp['Temp. A..1'].tolist()
Mintemp=[]
thing=[]
b=[]
for x in Min:
    thing=re.findall('\d{2}[:]\d{2}([-]?)(\d+)([,])?(\d+)?\s',x)
    if thing[0][2]=="":
        b=float(thing[0][0]+thing[0][1])
        print('yay')
    else: 
        b=float(thing[0][0]+thing[0][1]+'.'+thing[0][3])
    Mintemp.append(b)
len(Mintemp)
#for x in Mintemp:
 #   if re.findall('[.](\d)?',str(x))!='':
  #      print(re.findall('[.](\d)?',str(x)))
# Out:
# 292

# %% [markdown]
# min

# %%
Max=temp['Temp. A..2'].tolist()
Maxtemp=[]
thing=[]
b=[]
for x in Max:
    thing=re.findall('\d{2}[:]\d{2}([-]?)(\d+)([,])?(\d+)?\s',x)
    if thing[0][2]=="":
        b=float(thing[0][0]+thing[0][1])
    else: 
        b=float(thing[0][0]+thing[0][1]+'.'+thing[0][3])
    Maxtemp.append(b)

# %%
x=np.array(Mintemp)
y=np.array(Maxtemp)
temp['min_temp']= x
temp['max_temp']= y
temp
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#           Datum Temp. A.         Temp. A..1         Temp. A..2  min_temp  \
# 0    01.01.2019   6,3 °C   Min. 23:505,3 °C   Max. 12:556,9 °C       5.3
# 1    02.01.2019   3,5 °C  Min. 23:55-1,8 °C   Max. 14:156,4 °C      -1.8
# 2    03.01.2019  -1,0 °C  Min. 06:20-3,9 °C   Max. 19:050,8 °C      -3.9
# 3    04.01.2019   1,3 °C  Min. 01:25-0,3 °C   Max. 14:302,9 °C      -0.3
# 4    05.01.2019   2,9 °C   Min. 09:351,7 °C   Max. 23:454,6 °C       1.7
# ..          ...      ...                ...                ...       ...
# 287  15.10.2019  16,2 °C  Min. 08:0013,2 °C  Max. 12:4521,6 °C      13.2
# 288  16.10.2019  13,6 °C  Min. 04:2011,1 °C  Max. 17:5017,2 °C      11.1
# 289  17.10.2019  14,9 °C  Min. 01:4012,1 °C  Max. 14:4019,0 °C      12.1
# 290  18.10.2019  14,3 °C  Min. 22:3511,4 °C  Max. 12:1017,7 °C      11.4
# 291  19.10.2019  13,7 °C  Min. 00:3511,2 °C  Max. 16:2516,4 °C      11.2
#
#      max_temp
# 0         6.9
# 1         6.4
# 2         0.8
# 3         2.9
# 4         4.6
# ..        ...
# 287      21.6
# 288      17.2
# 289      19.0
# 290      17.7
# 291      16.4
#
# [292 rows x 6 columns]

# %%
# Out:
# array(['Min. 23:505,3 °C', 'Min. 23:55-1,8 °C', 'Min. 06:20-3,9 °C',
#        'Min. 01:25-0,3 °C', 'Min. 09:351,7 °C', 'Min. 23:504,5 °C',
#        'Min. 23:103,2 °C', 'Min. 01:203,1 °C', 'Min. 23:451,1 °C',
#        'Min. 23:50-0,7 °C', 'Min. 02:10-0,7 °C', 'Min. 00:000,5 °C',
#        'Min. 00:004,3 °C', 'Min. 22:052,3 °C', 'Min. 06:051,8 °C',
#        'Min. 23:503,9 °C', 'Min. 23:202,2 °C', 'Min. 21:25-0,4 °C',
#        'Min. 23:55-2,7 °C', 'Min. 08:00-5,0 °C', 'Min. 08:45-5,3 °C',
#        'Min. 04:15-6,7 °C', 'Min. 07:10-2,2 °C', 'Min. 08:00-3,2 °C',
#        'Min. 06:50-3,2 °C', 'Min. 01:20-0,2 °C', 'Min. 23:552,8 °C',
#        'Min. 23:451,2 °C', 'Min. 07:050,8 °C', 'Min. 23:550,2 °C',
#        'Min. 02:10-1,2 °C', 'Min. 02:401,5 °C', 'Min. 07:152,6 °C',
#        'Min. 23:352,3 °C', 'Min. 07:55-2,4 °C', 'Min. 04:55-0,1 °C',
#        'Min. 07:50-2,2 °C', 'Min. 00:05-1,6 °C', 'Min. 00:003,7 °C',
#        'Min. 05:005,9 °C', 'Min. 22:405,1 °C', 'Min. 23:301,9 °C',
#        'Min. 03:000,5 °C', 'Min. 08:30-1,9 °C', 'Min. 08:00-2,7 °C',
#        'Min. 05:45-1,3 °C', 'Min. 08:05-0,4 °C', 'Min. 07:50-1,1 °C',
#        'Min. 07:000,2 °C', 'Min. 23:553,3 °C', 'Min. 07:35-0,4 °C',
#        'Min. 02:352,7 °C', 'Min. 21:457,7 °C', 'Min. 07:553,7 °C',
#        'Min. 08:000,1 °C', 'Min. 07:150,9 °C', 'Min. 07:500,7 °C',
#        'Min. 07:200,8 °C', 'Min. 00:255,0 °C', 'Min. 23:307,4 °C',
#        'Min. 04:006,3 °C', 'Min. 02:309,1 °C', 'Min. 23:206,2 °C',
#        'Min. 05:355,3 °C', 'Min. 05:505,1 °C', 'Min. 21:257,3 °C',
#        'Min. 08:006,9 °C', 'Min. 00:357,2 °C', 'Min. 22:155,7 °C',
#        'Min. 06:253,7 °C', 'Min. 06:451,7 °C', 'Min. 23:155,1 °C',
#        'Min. 00:005,1 °C', 'Min. 02:055,6 °C', 'Min. 22:457,3 °C',
#        'Min. 23:503,8 °C', 'Min. 04:302,2 °C', 'Min. 06:450,8 °C',
#        'Min. 07:00-1,6 °C', 'Min. 07:100,3 °C', 'Min. 06:502,3 °C',
#        'Min. 04:454,6 °C', 'Min. 07:002,7 °C', 'Min. 06:002,1 °C',
#        'Min. 02:402,4 °C', 'Min. 02:104,3 °C', 'Min. 06:300,3 °C',
#        'Min. 06:306,1 °C', 'Min. 07:004,9 °C', 'Min. 07:304,3 °C',
#        'Min. 08:307,9 °C', 'Min. 07:5010,2 °C', 'Min. 23:155,3 °C',
#        'Min. 03:254,8 °C', 'Min. 06:004,3 °C', 'Min. 07:352,5 °C',
#        'Min. 07:207,2 °C', 'Min. 23:558,5 °C', 'Min. 00:308,3 °C',
#        'Min. 07:208,6 °C', 'Min. 07:002,8 °C', 'Min. 07:351,7 °C',
#        'Min. 23:403,2 °C', 'Min. 05:551,7 °C', 'Min. 07:051,2 °C',
#        'Min. 08:006,3 °C', 'Min. 07:0010,4 °C', 'Min. 06:2512,7 °C',
#        'Min. 06:3512,9 °C', 'Min. 07:2010,0 °C', 'Min. 07:1010,7 °C',
#        'Min. 07:0515,7 °C', 'Min. 06:4514,3 °C', 'Min. 23:3010,3 °C',
#        'Min. 02:359,7 °C', 'Min. 04:458,6 °C', 'Min. 23:506,4 °C',
#        'Min. 05:404,8 °C', 'Min. 05:103,7 °C', 'Min. 07:159,0 °C',
#        'Min. 06:456,1 °C', 'Min. 06:256,9 °C', 'Min. 06:309,4 °C',
#        'Min. 10:254,2 °C', 'Min. 06:101,9 °C', 'Min. 06:305,4 °C',
#        'Min. 06:252,3 °C', 'Min. 01:259,7 °C', 'Min. 05:108,8 °C',
#        'Min. 06:458,9 °C', 'Min. 23:459,0 °C', 'Min. 04:555,5 °C',
#        'Min. 06:005,7 °C', 'Min. 04:307,3 °C', 'Min. 06:304,8 °C',
#        'Min. 01:558,9 °C', 'Min. 06:259,0 °C', 'Min. 05:5010,6 °C',
#        'Min. 04:5511,6 °C', 'Min. 06:2012,2 °C', 'Min. 23:0512,1 °C',
#        'Min. 23:5510,7 °C', 'Min. 06:056,8 °C', 'Min. 06:059,6 °C',
#        'Min. 06:4512,2 °C', 'Min. 06:1510,4 °C', 'Min. 06:1013,5 °C',
#        'Min. 23:5512,4 °C', 'Min. 03:0011,1 °C', 'Min. 06:108,4 °C',
#        'Min. 03:1013,4 °C', 'Min. 06:0513,1 °C', 'Min. 06:1015,1 °C',
#        'Min. 06:0516,6 °C', 'Min. 06:2015,4 °C', 'Min. 06:0019,7 °C',
#        'Min. 23:5011,3 °C', 'Min. 02:2010,2 °C', 'Min. 06:3513,4 °C',
#        'Min. 05:359,8 °C', 'Min. 05:4515,8 °C', 'Min. 06:0513,6 °C',
#        'Min. 11:0013,8 °C', 'Min. 06:5514,3 °C', 'Min. 01:4016,8 °C',
#        'Min. 05:4015,3 °C', 'Min. 06:4515,6 °C', 'Min. 06:0513,0 °C',
#        'Min. 06:1016,1 °C', 'Min. 05:2518,2 °C', 'Min. 04:1016,4 °C',
#        'Min. 06:3516,5 °C', 'Min. 05:5514,3 °C', 'Min. 05:1015,6 °C',
#        'Min. 05:3021,3 °C', 'Min. 06:2023,3 °C', 'Min. 06:0521,3 °C',
#        'Min. 06:3523,2 °C', 'Min. 06:3016,5 °C', 'Min. 06:0516,7 °C',
#        'Min. 06:4521,3 °C', 'Min. 23:5522,9 °C', 'Min. 06:2017,1 °C',
#        'Min. 06:1516,9 °C', 'Min. 06:3014,3 °C', 'Min. 06:0014,6 °C',
#        'Min. 06:3016,7 °C', 'Min. 07:1016,7 °C', 'Min. 06:0514,2 °C',
#        'Min. 06:0510,9 °C', 'Min. 06:259,4 °C', 'Min. 06:3016,4 °C',
#        'Min. 23:5515,7 °C', 'Min. 04:4514,3 °C', 'Min. 04:4514,0 °C',
#        'Min. 05:4512,5 °C', 'Min. 06:3010,7 °C', 'Min. 06:3012,7 °C',
#        'Min. 06:0013,8 °C', 'Min. 04:0019,8 °C', 'Min. 05:3017,4 °C',
#        'Min. 06:2520,4 °C', 'Min. 06:4016,2 °C', 'Min. 06:3517,5 °C',
#        'Min. 06:4022,1 °C', 'Min. 06:3521,1 °C', 'Min. 07:2024,8 °C',
#        'Min. 23:3518,6 °C', 'Min. 23:4518,6 °C', 'Min. 05:3018,2 °C',
#        'Min. 06:5017,8 °C', 'Min. 06:2518,2 °C', 'Min. 05:0515,5 °C',
#        'Min. 06:0516,1 °C', 'Min. 05:3515,9 °C', 'Min. 06:3014,2 °C',
#        'Min. 03:5019,2 °C', 'Min. 23:5019,5 °C', 'Min. 23:5017,6 °C',
#        'Min. 06:3017,0 °C', 'Min. 06:3017,0 °C', 'Min. 23:5519,2 °C',
#        'Min. 21:0015,6 °C', 'Min. 06:1514,7 °C', 'Min. 06:5513,4 °C',
#        'Min. 04:4513,9 °C', 'Min. 00:3016,4 °C', 'Min. 07:0014,1 °C',
#        'Min. 22:0017,6 °C', 'Min. 01:3017,3 °C', 'Min. 08:0018,1 °C',
#        'Min. 07:0515,7 °C', 'Min. 04:0014,1 °C', 'Min. 07:0012,3 °C',
#        'Min. 07:1512,7 °C', 'Min. 07:0014,1 °C', 'Min. 07:1516,6 °C',
#        'Min. 07:0017,7 °C', 'Min. 07:2519,5 °C', 'Min. 04:5521,8 °C',
#        'Min. 06:2520,8 °C', 'Min. 07:2018,7 °C', 'Min. 07:3517,6 °C',
#        'Min. 23:5518,7 °C', 'Min. 07:0514,3 °C', 'Min. 07:259,7 °C',
#        'Min. 07:1010,7 °C', 'Min. 08:3015,5 °C', 'Min. 08:0010,3 °C',
#        'Min. 03:459,9 °C', 'Min. 04:5512,2 °C', 'Min. 07:1511,8 °C',
#        'Min. 07:058,6 °C', 'Min. 07:408,0 °C', 'Min. 23:5016,8 °C',
#        'Min. 04:3514,4 °C', 'Min. 07:5013,1 °C', 'Min. 07:1511,9 °C',
#        'Min. 07:3511,7 °C', 'Min. 23:5012,6 °C', 'Min. 07:457,9 °C',
#        'Min. 06:407,1 °C', 'Min. 08:058,6 °C', 'Min. 07:0512,7 °C',
#        'Min. 08:2010,5 °C', 'Min. 07:4514,2 °C', 'Min. 07:5011,3 °C',
#        'Min. 07:0013,9 °C', 'Min. 03:4513,7 °C', 'Min. 23:3013,1 °C',
#        'Min. 08:0012,9 °C', 'Min. 05:0012,6 °C', 'Min. 23:5513,1 °C',
#        'Min. 02:5011,9 °C', 'Min. 23:558,3 °C', 'Min. 06:055,5 °C',
#        'Min. 01:507,2 °C', 'Min. 22:359,9 °C', 'Min. 11:459,1 °C',
#        'Min. 07:509,1 °C', 'Min. 06:0011,4 °C', 'Min. 23:559,6 °C',
#        'Min. 00:409,2 °C', 'Min. 03:059,5 °C', 'Min. 00:0011,7 °C',
#        'Min. 08:4013,8 °C', 'Min. 08:3513,4 °C', 'Min. 08:0013,2 °C',
#        'Min. 04:2011,1 °C', 'Min. 01:4012,1 °C', 'Min. 22:3511,4 °C',
#        'Min. 00:3511,2 °C'], dtype='<U17')
